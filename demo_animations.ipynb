# %%
from ising_model import ClassicIsing
import electron
from grid import Grid, HoleGrid, Mobius, Cylinder, Torus
import numpy as np
from IPython.display import Video
from visualizations import animate_ising

# Before running the code, make sure to reset the kernel to clear any old imports.

# %% [markdown]
# ## Regular Grid

# %%
newGrid = Grid(n_x=10, n_y=10, gridPointObject=electron.ClassicElectron, random_seed=12)
isingModel = ClassicIsing(newGrid, temperature=1, ferromagnetivity=.1,Mf_External=0,)

isingModel.runSimulation(1000)


ani = animate_ising(newGrid, isingModel.grid.grid_history, interval=50, title="Regular Grid Evolution")

# save animation as gif (the animation won't render on VS Code so download to your computer)
ani.save('ising_evolution_regular.gif', writer='ffmpeg', fps=20)

# if using Google Colab, save it as mp4 and embed it
# ani.save('ising_evolution.mp4', writer='ffmpeg', fps=20)
# Video('ising_evolution.mp4', embed=True)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ## Hole Grid

# %%
holeGrid = HoleGrid(n_x=10, n_y=10, gridPointObject=electron.ClassicElectron, random_seed=2, hole_grid=np.ones((3,3)) ,c_y=2, c_x=2)
isingModel = ClassicIsing(holeGrid, temperature=1, ferromagnetivity=1,Mf_External=0,)

isingModel.runSimulation(10)

ani = animate_ising(holeGrid, isingModel.grid.grid_history, interval=100, title="Hole Grid Evolution")

ani.save('ising_evolution_hole.gif', writer='ffmpeg', fps=10)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ## Mobius Grid

# %%
mobiusGrid = Mobius(n_x=10, n_y=10, gridPointObject=electron.ClassicElectron, random_seed=2)
isingModel = ClassicIsing(mobiusGrid, temperature=1, ferromagnetivity=1,Mf_External=0,)

isingModel.runSimulation(10)

ani = animate_ising(mobiusGrid, isingModel.grid.grid_history, interval=100, title="Mobius Grid Evolution")

ani.save('ising_evolution_mobius.gif', writer='ffmpeg', fps=10)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ## Cylinder Grid

# %%
cylinderGrid = Cylinder(n_x=10, n_y=10, gridPointObject=electron.ClassicElectron, random_seed=2)
isingModel = ClassicIsing(cylinderGrid, temperature=1, ferromagnetivity=1,Mf_External=0,)

isingModel.runSimulation(10)

ani = animate_ising(cylinderGrid, isingModel.grid.grid_history, interval=100, title="Cylinder Grid Evolution")

ani.save('ising_evolution_cylinder.gif', writer='ffmpeg', fps=10)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ## Torus Grid

# %%
torusGrid = Torus(n_x=10, n_y=10, gridPointObject=electron.ClassicElectron, random_seed=2)
isingModel = ClassicIsing(torusGrid, temperature=10, ferromagnetivity=1,Mf_External=0,)

isingModel.runSimulation(10)

ani = animate_ising(torusGrid, isingModel.grid.grid_history, interval=100, title="Torus Grid Evolution")

ani.save('ising_evolution_torus.gif', writer='ffmpeg', fps=10)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
